# %% [markdown]
# <a href="https://colab.research.google.com/github/christeeno/TensorFlow/blob/main/ImplemntingCallback.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
fminst=tf.keras.datasets.fashion_mnist

# %%
(x_train,y_train),(x_test,y_test)=fminst.load_data()
x_train,x_test=x_train/255.0,x_test/255.0
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
class MyCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self,epoch,logs=None):
    if logs['loss']<0.4:
      print("the loss is lower than 0.4 hence ending the training")
      self.model.stop_training=True

# %%
model=tf.keras.models.Sequential([
    tf.keras.Input(shape=(28,28)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=10,callbacks=[MyCallback()])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step - accuracy: 0.7935 - loss: 0.5904
# Epoch 2/10
# 1871/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8661 - loss: 0.3663the loss is lower than 0.4 hence ending the training
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 36s 8ms/step - accuracy: 0.8661 - loss: 0.3663
